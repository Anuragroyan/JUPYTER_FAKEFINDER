# %%
import pandas as pd # provide rows & columns for analysis
import numpy as np #  provide multidimensional array
from matplotlib import pyplot as plt  # provide plotting of 2d graphs
# %matplotlib inline

# %%
data = pd.read_csv('news_datasets.csv', index_col=[0])

# %%
data.head()
# Out:
#                                                    title  \
# 8476                        You Can Smell Hillary’s Fear
# 10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 3608         Kerry to go to Paris in gesture of sympathy
# 10142  Bernie supporters on Twitter erupt in anger ag...
# 875     The Battle of New York: Why This Primary Matters
#
#                                                     text label
# 8476   Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 10294  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 3608   U.S. Secretary of State John F. Kerry said Mon...  REAL
# 10142  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 875    It's primary day in New York and front-runners...  REAL

# %%
data['Title_Len'] = data['title'].apply(lambda x: len(x))
data['Text_Len'] = data['text'].apply(lambda x: len(x))
data.head(10)
# Out:
#                                                    title  \
# 8476                        You Can Smell Hillary’s Fear
# 10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 3608         Kerry to go to Paris in gesture of sympathy
# 10142  Bernie supporters on Twitter erupt in anger ag...
# 875     The Battle of New York: Why This Primary Matters
# 6903                                         Tehran, USA
# 7341   Girl Horrified At What She Watches Boyfriend D...
# 95                     ‘Britain’s Schindler’ Dies at 106
# 4869   Fact check: Trump and Clinton at the 'commande...
# 2909   Iran reportedly makes new push for uranium con...
#
#                                                     text label  Title_Len  \
# 8476   Daniel Greenfield, a Shillman Journalism Fello...  FAKE         28
# 10294  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE         85
# 3608   U.S. Secretary of State John F. Kerry said Mon...  REAL         43
# 10142  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE         84
# 875    It's primary day in New York and front-runners...  REAL         48
# 6903     \nI’m not an immigrant, but my grandparents ...  FAKE         11
# 7341   Share This Baylee Luciani (left), Screenshot o...  FAKE         73
# 95     A Czech stockbroker who saved more than 650 Je...  REAL         33
# 4869   Hillary Clinton and Donald Trump made some ina...  REAL         63
# 2909   Iranian negotiators reportedly have made a las...  REAL         71
#
#        Text_Len
# 8476       7518
# 10294      2646
# 3608       2543
# 10142      2660
# 875        1840
# 6903      13333
# 7341       3171
# 95          783
# 4869      13863
# 2909       4296

# %%
import string
def punctuation_count(txt):
    count = sum((1 for c in txt if c in string.punctuation))
    return 100*count/len(txt)
data['punctuation_%_title'] = data['title'].apply(lambda x : punctuation_count(x))
data['punctuation_%_text'] = data['text'].apply(lambda x : punctuation_count(x))
data.head(10)
# Out:
#                                                    title  \
# 8476                        You Can Smell Hillary’s Fear
# 10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 3608         Kerry to go to Paris in gesture of sympathy
# 10142  Bernie supporters on Twitter erupt in anger ag...
# 875     The Battle of New York: Why This Primary Matters
# 6903                                         Tehran, USA
# 7341   Girl Horrified At What She Watches Boyfriend D...
# 95                     ‘Britain’s Schindler’ Dies at 106
# 4869   Fact check: Trump and Clinton at the 'commande...
# 2909   Iran reportedly makes new push for uranium con...
#
#                                                     text label  Title_Len  \
# 8476   Daniel Greenfield, a Shillman Journalism Fello...  FAKE         28
# 10294  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE         85
# 3608   U.S. Secretary of State John F. Kerry said Mon...  REAL         43
# 10142  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE         84
# 875    It's primary day in New York and front-runners...  REAL         48
# 6903     \nI’m not an immigrant, but my grandparents ...  FAKE         11
# 7341   Share This Baylee Luciani (left), Screenshot o...  FAKE         73
# 95     A Czech stockbroker who saved more than 650 Je...  REAL         33
# 4869   Hillary Clinton and Donald Trump made some ina...  REAL         63
# 2909   Iranian negotiators reportedly have made a las...  REAL         71
#
#        Text_Len  punctuation_%_title  punctuation_%_text
# 8476       7518             0.000000            1.423251
# 10294      2646             2.352941            2.380952
# 3608       2543             0.000000            1.690916
# 10142      2660             4.761905            3.007519
# 875        1840             2.083333            3.532609
# 6903      13333             9.090909            2.392560
# 7341       3171             0.000000            1.860612
# 95          783             0.000000            1.787995
# 4869      13863             7.936508            1.983698
# 2909       4296             0.000000            2.164804

# %%
bins = np.linspace(0, 140, 50)
pyplot.hist(data[data['label'] == 'FAKE']['Title_Len'], bins, label='FAKE', density=True)
pyplot.hist(data[data['label'] == 'REAL']['Title_Len'], bins, label='REAL', density=True)
pyplot.legend(loc='upper left')
pyplot.show()

# %%
bins = np.linspace(0, 170, 50)
pyplot.hist(data[data['label'] == 'FAKE']['Text_Len'], bins, label='FAKE', density=True)
pyplot.hist(data[data['label'] == 'REAL']['Text_Len'], bins, label='REAL', density=True)
pyplot.legend(loc='upper right')
pyplot.show()
