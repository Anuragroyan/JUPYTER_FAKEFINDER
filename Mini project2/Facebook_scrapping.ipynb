# %%
import http.cookiejar
import urllib.request
import requests
import bs4

# %%
# Store the cookies and create an opener that will hold it
cj = http.cookiejar.CookieJar()
opener = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))

# %%
# Add our headers
opener.addheaders = [('User-agent', 'dfdf')]

# %%
# Install our opener (note that this changes the global opener to the one
# we just made, but you can also just call opener.open() if you want)
urllib.request.install_opener(opener)

# %%
# The action/ target from the form
authentication_url = 'https://m.facebook.com/login.php'

# %%
# Input parameters we are going to send
payload = {
  'email': 'anuragroy010@gmail.com',
  'pass': 'Anurag!10'
  }

# %%
# Use urllib to encode the payload
data = urllib.parse.urlencode(payload).encode("utf-8")

# %%
# Build our Request object (supplying 'data' makes it a POST)
req = urllib.request.Request(authentication_url, data)

# %%
# Make the request and read the response
resp = urllib.request.urlopen(req)
contents = resp.read()
print(contents)
# Out:
# b'<?xml version="1.0" encoding="utf-8"?>\n<!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd"><html xmlns="http://www.w3.org/1999/xhtml"><head><title>Facebook</title><meta name="referrer" content="default" id="meta_referrer" /><style type="text/css" nonce="XCiYwEKQ">/*<![CDATA[*/.bk{padding:6px;}.b .bl{padding:2px 4px;}.b .ch{border:1px solid #8d949e;border-radius:72px;height:45px;padding:4px 20px 0 20px;resize:none;}.cf{border-color:#90949c;box-sizing:border-box;width:100%;}.cf.cg{margin-top:6px;}.b .cj{height:45px;margin:6px 0 0 5px;width:75px;}.b .cb{border:1px solid #8d949e;height:43px;margin:6px 4px;width:43px;}.ca{padding-right:4px;}.ci{padding-left:4px;}.bn{margin-top:4px;}.bx{display:inline-block;}.bx .by{color:#4b4f56;display:block;font-size:small;text-align:left;white-space:normal;}.de{background:#f5f6f7;}.d{background:#dddfe2;}.db{background:#fff;}form{margin:0;border:0;}.b .m{border:0;border-collapse:collapse;marg
# ...

# %%
url = "https://m.facebook.com/enstein.roy/friends"
data = requests.get(url, cookies=cj)
soup = bs4.BeautifulSoup(data.text, 'html.parser')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Anurag Roy
#   </title>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <style nonce="kWlHq3wl" type="text/css">
# ...

# %%
z = 0
for i in soup.find_all('a'):
    if z>21:
        if i.text.lower()=="see more friends":
            break
        elif i.text!= "Add Friend":
            print(i.text)
    z = z+1
# Out:
# Seema Roy
# Arun Kumar Roy
# Ashutosh Yadav
# Mohammed Yaseen
# Abhay Yadav
# Ananth Somanath
# Shekhar Kotnala
# Aditya Gangwar
# Sanghadeep Dutta
# Shishir Sharma
# Abhishek Sharma
# Mayank Pall
# Arindam Roy
# Shekhar Kotnala
# Shubham Sarraf
# Puneet Pandey
# Saif Khan
# Sabyasachi Bhattacharya
# Siddharth Gupta
# Lokendra Kapoor
# Anirban Chakraborty
# Shubham Sinha
# Shankar Tikader
# Vaibhav Pitale
